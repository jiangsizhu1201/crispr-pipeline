# %%
# %%bash
# nextflow run main.nf -profile test,singularity -resume
# Out:
# Nextflow 24.10.5 is available - Please consider updating your version to it
#  N E X T F L O W   ~  version 24.04.4
#
# Launching `main.nf` [agitated_mestorf] DSL2 - revision: 9dfc1d8eee
#
# WARN: Access to undefined parameter `validate_params` -- Initialise it to a default value eg. `params.validate_params = some_value`
# [-        ] NFC…guideWorkflow:seqSpecCheck -
# [-        ] NFC…:hashWorkflow:seqSpecCheck -
# [-        ] NFC…ng_pipeline:downloadGenome -
#
# [-        ] NFC…guideWorkflow:seqSpecCheck -
# [-        ] NFC…:hashWorkflow:seqSpecCheck -
# [-        ] NFC…ng_pipeline:downloadGenome -
# [-        ] NFC…pipeline:prepare_covariate -
# [-        ] NFC…rna_pipeline:seqSpecParser -
# [-        ] NFC…pipeline:downloadReference -
# [-        ] NFC…_rna_pipeline:mappingscRNA -
# [-        ] NFC…na_pipeline:anndata_concat -
# [-        ] NFC…ide_pipeline:seqSpecParser -
# [-        ] NFC…de_pipeline:createGuideRef -
# [-        ] NFC…uide_pipeline:mappingGuide -
# ...
